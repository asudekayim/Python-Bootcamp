# %%
from notifications import Notification, EmailNotification, SMSNotification, PushNotification
from utils import generate_message

# %%
email = EmailNotification(generate_message())
sms = SMSNotification(generate_message())
push = PushNotification(generate_message())

# %%
notifications = [email, sms, push]

# %%
for notification in notifications:
    notification.send()
# Out:
# Email gönderildi: 450 TL harcama yapıldı.💳(19.04.2026 16:58)
# SMS gönderildi: Günlük ödülün seni bekliyor!✨(19.04.2026 16:58)
# Push bildirimi gönderildi: Kargon dağıtıma çıktı!📦(19.04.2026 16:58)

# %%
print(email)
# __str__() bir nesnenin print ile bastırılınca ne döndüreceğini söyleyen metottur. 
# Eğer bu base class'ta tanımlanmazsa, print edince gördüğümüz şey bellekte tutulduğu adres olacaktır.
# Out:
# 450 TL harcama yapıldı.💳(19.04.2026 16:58)

# %%
message = Notification(generate_message())
len(message)
# Out:
# 42

# %%
print(len(message))
# Out:
# 42

# %%
print(message)
# Out:
# Bugünkü dersini unutma!🔥(19.04.2026 16:58)

# %%
# len(message), Notification sınıfında yazığımız __len__ metodunun
# çalıştırılıp döndürülmesidir diyebiliriz.

# %%
try:
    bosMesaj = Notification(" ")
except ValueError as e:
    print(e)
# Out:
# Bildirim mesajı boş
