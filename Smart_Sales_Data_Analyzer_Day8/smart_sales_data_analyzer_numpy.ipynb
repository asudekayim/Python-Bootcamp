# %%
import numpy as np

# %%
ornek = np.random.randint(50,300, size=(7,5))

# %%
ornek
# Out:
# array([[ 95, 199, 240,  77,  91],
#        [220, 156,  86, 272,  72],
#        [ 54,  68, 296, 130, 288],
#        [250,  72, 221, 156,  70],
#        [218,  89, 148, 146, 187],
#        [123,  66, 105, 257, 207],
#        [256, 194, 187, 135,  50]], dtype=int32)

# %%
ornek.shape
# kaç satır kaç sütün
# Out:
# (7, 5)

# %%
ornek.ndim
## dizinin kaç boyutlu olduğunu söyler
# Out:
# 2

# %%
ornek.dtype
# veri tipi nedir?
# Out:
# dtype('int32')

# %%
ornek.size
# toplam eleman sayısı
# Out:
# 35

# %%
ornek[2]
# belirli bir günün satışları
# Out:
# array([ 54,  68, 296, 130, 288], dtype=int32)

# %%
ornek[:, 4]
# belirli bir ürünün haftalık satışı
# Out:
# array([ 91,  72, 288,  70, 187, 207,  50], dtype=int32)

# %%
ornek[:3]
#ilk 3 gün
# Out:
# array([[ 95, 199, 240,  77,  91],
#        [220, 156,  86, 272,  72],
#        [ 54,  68, 296, 130, 288]], dtype=int32)

# %%
toplam = ornek.sum()

# %%
ornek.mean()
# Out:
# np.float64(156.6)

# %%
ornek.max()
# Out:
# np.int32(296)

# %%
ornek.min()
# Out:
# np.int32(50)

# %%
ayniUrunToplami = ornek.sum(axis = 0)

# %%
ayniUrunToplami
# Out:
# array([1216,  844, 1283, 1173,  965])

# %%
gunlerToplami = ornek.sum(axis = 1)

# %%
gunlerToplami
# Out:
# array([702, 806, 836, 769, 788, 758, 822])

# %%
# axis = 0 aşağı doğru, axis = 1 yana doğru çalışır

# %%
yeniOrnek = ornek.reshape(35,1)

# %%
yeniOrnek
# Out:
# array([[ 95],
#        [199],
#        [240],
#        [ 77],
#        [ 91],
#        [220],
#        [156],
#        [ 86],
#        [272],
#        [ 72],
#        [ 54],
#        [ 68],
#        [296],
#        [130],
#        [288],
#        [250],
#        [ 72],
#        [221],
#        [156],
#        [ 70],
#        [218],
#        [ 89],
#        [148],
#        [146],
#        [187],
#        [123],
#        [ 66],
#        [105],
#        [257],
#        [207],
#        [256],
#        [194],
#        [187],
#        [135],
#        [ 50]], dtype=int32)

# %%
ornek.transpose()
# Out:
# array([[ 95, 220,  54, 250, 218, 123, 256],
#        [199, 156,  68,  72,  89,  66, 194],
#        [240,  86, 296, 221, 148, 105, 187],
#        [ 77, 272, 130, 156, 146, 257, 135],
#        [ 91,  72, 288,  70, 187, 207,  50]], dtype=int32)

# %%
ornek.flatten()
# Out:
# array([ 95, 199, 240,  77,  91, 220, 156,  86, 272,  72,  54,  68, 296,
#        130, 288, 250,  72, 221, 156,  70, 218,  89, 148, 146, 187, 123,
#         66, 105, 257, 207, 256, 194, 187, 135,  50], dtype=int32)

# %%
ornek.ravel()
# Out:
# array([ 95, 199, 240,  77,  91, 220, 156,  86, 272,  72,  54,  68, 296,
#        130, 288, 250,  72, 221, 156,  70, 218,  89, 148, 146, 187, 123,
#         66, 105, 257, 207, 256, 194, 187, 135,  50], dtype=int32)

# %%
print(f"Toplam haftalık satış: {toplam}")
a = ayniUrunToplami.argmax()
print(f"En çok satan ürün: {a}.sütun")
b = gunlerToplami.argmax()
print(f"En çok satan gün: {b}.gün")
# Out:
# Toplam haftalık satış: 5481
# En çok satan ürün: 2.sütun
# En çok satan gün: 2.gün
