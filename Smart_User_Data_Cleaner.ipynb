# %%
raw_data ="  AhMeT  yILMAZ ;  23 ;  1.78 ;  ahmetYILMAZ@GMAIL.Com   "

# %%
x = raw_data.strip().split(";")

# %%
x
# Out:
# ['AhMeT  yILMAZ ', '  23 ', '  1.78 ', '  ahmetYILMAZ@GMAIL.Com']

# %%
#isim

# %%
fullName = x[0].strip().split()
fullName
# Out:
# ['AhMeT', 'yILMAZ']

# %%
name = fullName[0].capitalize()

# %%
surname = fullName[1].capitalize()

# %%
name, surname
# Out:
# ('Ahmet', 'Yilmaz')

# %%
#yaş

# %%
age = x[1].strip()
age
# Out:
# '23'

# %%
age = int(age)
age
# Out:
# 23

# %%
age = float(age + 10)
age
# Out:
# 33.0

# %%
#boy

# %%
height = x[2].strip()
height
# Out:
# '1.78'

# %%
height = float(height)

# %%
cm_height = height * 100

# %%
cm_height
# Out:
# 178.0

# %%
#email temizleme

# %%
email = x[3].strip().lower()

# %%
email
# Out:
# 'ahmetyilmaz@gmail.com'

# %%
index = email.find("@")
index
# Out:
# 11

# %%
mail_kullaniciAdi = email[:index]
mail_kullaniciAdi
# Out:
# 'ahmetyilmaz'

# %%
kod = mail_kullaniciAdi[:3]
kod
# Out:
# 'ahm'

# %%
print(f"Kullanıcı Adi: {name} {surname}\nYaş(10 yıl sonra): {age}\nBoy(cm): {cm_height}\nEmail kullanıcı kodu: {kod}")
# Out:
# Kullanıcı Adi: Ahmet Yilmaz
# Yaş(10 yıl sonra): 33.0
# Boy(cm): 178.0
# Email kullanıcı kodu: ahm
